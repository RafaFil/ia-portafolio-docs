# %% [markdown]
# # UT3 - ALGORITMOS LINEALES
#
# ## TA4 - Dataset sport-training.csv
#
# Discriminante Lineal utilizando Python y scikit-learn

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
input_file = "sports_Training.csv"
d_training = pd.read_csv(input_file, header=0)
d_training
# Out:
#      Edad  Fuerza  Velocidad  Lesiones  Vision  Resistencia  Agilidad
# 0    15.1       3          2         1       2            3        29  \
# 1    15.4       3          2         0       3            5        18
# 2    13.6       5          5         0       2            5        27
# 3    18.8       5          1         1       1            3        48
# 4    16.1       3          1         0       3            3        38
# ..    ...     ...        ...       ...     ...          ...       ...
# 488  17.0       5          1         0       2            3        42
# 489  16.7       4          1         1       2            5        34
# 490  17.0       5          1         0       0            1        54
# 491  17.3       5          1         0       2            5        65
# 492  15.5       1          1         1       3            5        22
#
#      CapacidadDecision DeportePrimario
# 0                    4          Futbol
# 1                    8           Rugby
# ...

# %%
input_file = "sports_Scoring.csv"
d_scoring = pd.read_csv(input_file, header=0)
d_scoring
# Out:
#       Edad  Fuerza  Velocidad  Lesiones  Vision  Resistencia  Agilidad
# 0     18.5       5          1         1       0            5        33  \
# 1     13.3       1          2         1       3            5        18
# 2     13.4       2          1         0       2            5        40
# 3     13.6       4          1         0       0            5        28
# 4     16.3       3          1         0       2            5        32
# ...    ...     ...        ...       ...     ...          ...       ...
# 1836  17.2       5          3         1       1            5        36
# 1837  17.9       5          1         0       2            0        33
# 1838  14.5       5          4         0       0            3        49
# 1839  18.7       3          4         0       0            5        20
# 1840  13.8       5          6         1       1            6        52
#
#       CapacidadDecision
# 0                    61
# 1                    59
# 2                    11
# ...

# %%
data = d_training[(d_training['CapacidadDecision'] >= 3) & (d_training['CapacidadDecision'] <= 100)]
data
# Out:
#      Edad  Fuerza  Velocidad  Lesiones  Vision  Resistencia  Agilidad
# 0    15.1       3          2         1       2            3        29  \
# 1    15.4       3          2         0       3            5        18
# 2    13.6       5          5         0       2            5        27
# 3    18.8       5          1         1       1            3        48
# 4    16.1       3          1         0       3            3        38
# ..    ...     ...        ...       ...     ...          ...       ...
# 488  17.0       5          1         0       2            3        42
# 489  16.7       4          1         1       2            5        34
# 490  17.0       5          1         0       0            1        54
# 491  17.3       5          1         0       2            5        65
# 492  15.5       1          1         1       3            5        22
#
#      CapacidadDecision DeportePrimario
# 0                    4          Futbol
# 1                    8           Rugby
# ...

# %%
data_scor_filtred = d_scoring[(d_scoring['CapacidadDecision'] >= 3) & (d_scoring['CapacidadDecision'] <= 100)]
data_scor_filtred
# Out:
#       Edad  Fuerza  Velocidad  Lesiones  Vision  Resistencia  Agilidad
# 0     18.5       5          1         1       0            5        33  \
# 1     13.3       1          2         1       3            5        18
# 2     13.4       2          1         0       2            5        40
# 4     16.3       3          1         0       2            5        32
# 5     15.7       1          1         0       2            3        43
# ...    ...     ...        ...       ...     ...          ...       ...
# 1836  17.2       5          3         1       1            5        36
# 1837  17.9       5          1         0       2            0        33
# 1838  14.5       5          4         0       0            3        49
# 1839  18.7       3          4         0       0            5        20
# 1840  13.8       5          6         1       1            6        52
#
#       CapacidadDecision
# 0                    61
# 1                    59
# 2                    11
# ...

# %%
# colors = ("orange", "blue")
# plt.scatter(data['Fuerza'], data['Velocidad'], s=300, c=data['DeportePrimario'], 
# cmap=matplotlib.colors.ListedColormap(colors))
# plt.show()

# %%
X = data.loc[:, data.columns != 'DeportePrimario']
X
# Out:
#      Edad  Fuerza  Velocidad  Lesiones  Vision  Resistencia  Agilidad
# 0    15.1       3          2         1       2            3        29  \
# 1    15.4       3          2         0       3            5        18
# 2    13.6       5          5         0       2            5        27
# 3    18.8       5          1         1       1            3        48
# 4    16.1       3          1         0       3            3        38
# ..    ...     ...        ...       ...     ...          ...       ...
# 488  17.0       5          1         0       2            3        42
# 489  16.7       4          1         1       2            5        34
# 490  17.0       5          1         0       0            1        54
# 491  17.3       5          1         0       2            5        65
# 492  15.5       1          1         1       3            5        22
#
#      CapacidadDecision
# 0                    4
# 1                    8
# 2                   28
# 3                   36
# ...

# %%
y = data['DeportePrimario'].values
y
# Out:
# array(['Futbol', 'Rugby', 'Voleibol', 'Voleibol', 'Futbol', 'Futbol',
#        'Futbol', 'Basketball', 'Rugby', 'Voleibol', 'Futbol',
#        'Basketball', 'Basketball', 'Futbol', 'Rugby', 'Basketball',
#        'Futbol', 'Voleibol', 'Voleibol', 'Basketball', 'Voleibol',
#        'Basketball', 'Futbol', 'Voleibol', 'Futbol', 'Rugby',
#        'Basketball', 'Basketball', 'Voleibol', 'Voleibol', 'Basketball',
#        'Basketball', 'Voleibol', 'Voleibol', 'Rugby', 'Basketball',
#        'Basketball', 'Basketball', 'Voleibol', 'Voleibol', 'Basketball',
#        'Futbol', 'Rugby', 'Basketball', 'Futbol', 'Basketball',
#        'Basketball', 'Basketball', 'Rugby', 'Basketball', 'Futbol',
#        'Voleibol', 'Basketball', 'Rugby', 'Voleibol', 'Futbol', 'Rugby',
#        'Futbol', 'Futbol', 'Basketball', 'Voleibol', 'Voleibol', 'Rugby',
#        'Futbol', 'Voleibol', 'Futbol', 'Futbol', 'Futbol', 'Basketball',
#        'Futbol', 'Futbol', 'Voleibol', 'Basketball', 'Futbol', 'Futbol',
# ...

# %% [markdown]
# ### Parte 2: Entrenamiento

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X,y)
# Out:
# LinearDiscriminantAnalysis()

# %% [markdown]
# ### Parte 3: Evaluación

# %%
y_pred = lda.predict(data_scor_filtred)
print("Predicted")
pred = pd.DataFrame(y_pred)
pred.columns = ["DeportePrimario"]
pred
# Out:
# Predicted
#      DeportePrimario
# 0         Basketball
# 1              Rugby
# 2             Futbol
# 3              Rugby
# 4             Futbol
# ...              ...
# 1762          Futbol
# 1763          Futbol
# 1764          Futbol
# 1765      Basketball
# 1766          Futbol
#
# [1767 rows x 1 columns]
